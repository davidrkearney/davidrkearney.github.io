# %% [markdown]
# # Setting Up Computing Enviroment

# %% [markdown]
# ## Creating a virtual enviroment:

# %%
# !python -m venv ~/enviroments/dask

# %%
# !source ~/enviroments/dask/bin/activate

# %%
# !python -m venv dask

# %%
# !source ./dask/bin/activate

# %%
pip freeze > requirements_dask.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -r requirements_dask.txt
# Out:
# ite-packages (from -r requirements_dask.txt (line 15)) (0.10.0)
# ...

# %%
#!pip freeze > requirements.txt

# %%
from dask.distributed import Client

client = Client(processes=False, threads_per_worker=2,
                n_workers=3, memory_limit='4GB')
client
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/dev/Timeseries/timeseries/lib/python3.8/site-packages/dask/distributed.py in <module>
#       2 try:
# ----> 3     from distributed import *
#       4 except ImportError as e:
#
# ModuleNotFoundError: No module named 'distributed'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-ee7f61f324ba> in <module>
# ----> 1 from dask.distributed import Client
#       2
#       3 client = Client(processes=False, threads_per_worker=2,
#       4                 n_workers=3, memory_limit='4GB')
#       5 client
#
# ~/dev/Timeseries/timeseries/lib/python3.8/site-packages/dask/distributed.py in <module>
#       9         '  python -m pip install "dask[distributed]" --upgrade  # or python -m pip install'
#      10     )
# ...

# %%
# !pip freeze
# Out:
# alabaster==0.7.12
# argon2-cffi==20.1.0
# async-generator==1.10
# attrs==20.3.0
# Babel==2.9.0
# backcall==0.2.0
# beautifulsoup4==4.9.3
# bleach==3.2.1
# certifi==2020.11.8
# cffi==1.14.3
# chardet==3.0.4
# click==7.1.2
# cloudpickle==1.6.0
# colorama==0.4.4
# cycler==0.10.0
# dask==2.30.0
# decorator==4.4.2
# defusedxml==0.6.0
# docutils==0.16
# entrypoints==0.3
# fsspec==0.8.4
# gitdb==4.0.5
# GitPython==3.1.11
# HeapDict==1.0.1
# idna==2.10
# imagesize==1.2.0
# importlib-metadata==2.0.0
# inflection==0.5.1
# ipykernel==5.3.4
# ipython==7.19.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# jedi==0.17.2
# Jinja2==2.11.2
# json5==0.9.5
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-book==0.8.3
# jupyter-cache==0.4.1
# jupyter-client==6.1.7
# jupyter-console==6.2.0
# jupyter-core==4.6.3
# jupyter-sphinx==0.3.2
# jupyterlab==2.2.9
# jupyterlab-pygments==0.1.2
# jupyterlab-server==1.2.0
# kiwisolver==1.3.1
# latexcodec==2.0.1
# locket==0.2.0
# lxml==4.6.1
# markdown-it-py==0.5.6
# ...
